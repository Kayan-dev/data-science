# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = one-dimensional

# %%
colours = pd.Series(["red","blue","white"])
colours
# Out:
# 0      red
# 1     blue
# 2    white
# dtype: object

# %%
# DataFrame = two-dimensional
car_data = pd.DataFrame({"Car make":series, "Colour":colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    red
# 1   Toyota   blue
# 2    Honda  white

# %%
# Import data
car_sales = pd.read_csv("car-sales.csv")
car_sales_ext = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales-extended.csv")

# %%
car_sales
car_sales_ext
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
# exporting a dataframe
car_sales.to_csv("exported-car-sales.csv", index=False)
car_sales.to_excel
# Out:
# <bound method NDFrame.to_excel of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
export_car_sales = pd.read_csv("exported-car-sales.csv")
export_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Attribute
car_sales.dtypes

# Function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# car_sales_ext.index
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 1500, 112500])
car_prices.mean()
# Out:
# 39000.0

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
len(car_sales_ext)
# Out:
# 1000

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"],
                   index=[0,3,9,8,3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
# instead of car_sales["Make"]
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales.Make == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
## If plots dont show up,
## Then make sure to run these two lines of code:
# %matplotlib inline
import matplotlib.pyplot as plt
from jupyterthemes import jtplot

# you can select an alternative theme's plot style by name
# onedork | grade3 | oceans16 | chesterish | monokai | solarizedl | solarizedd
jtplot.style('chesterish')

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales_ext["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
##dtype('O') = Object
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-83bf2f29b5a6> in <module>
# ----> 1 car_sales["Price"].plot()
#
# /users/efe/Desktop/sample/env/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# /users/efe/Desktop/sample/env/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-3433c271f22e> in <module>
# ----> 1 car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)
#
# /users/efe/Desktop/sample/env/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5135             or name in self._accessors
#    5136         ):
# -> 5137             return object.__getattribute__(self, name)
#    5138         else:
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /users/efe/Desktop/sample/env/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
## the cents are included so how to change it?

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
## Check this link on how to deal with messy numbers:
## https://pbpython.com/currency-cleanup.html

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
## The Make hasnt been lowered cased
## To make it permanent, assign the values like this;
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_missing = pd.read_csv("car-sales-missing-data.csv")
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_missing["Odometer"].fillna(car_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
## To add the mean to the NaN you can do;
## car_missing["Odometer"] = car_missing["Odometer"].fillna(car_missing["Odometer"].mean())
## or the inplace parameter;
car_missing["Odometer"] = car_missing["Odometer"].fillna(car_missing["Odometer"].mean(),
                                                        inplace=False)
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White       NaN    4.0   $4,000
# 1   Honda    Red       NaN    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black       NaN    5.0  $22,000
# 4  Nissan  White       NaN    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White       NaN    NaN      NaN
# 9     NaN  White       NaN    4.0   $9,700

# %%
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White       NaN    4.0   $4,000
# 1   Honda    Red       NaN    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black       NaN    5.0  $22,000
# 4  Nissan  White       NaN    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White       NaN    NaN      NaN
# 9     NaN  White       NaN    4.0   $9,700

# %%
car_missing = pd.read_csv("car-sales-missing-data.csv")
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_missing_dropped = car_missing.dropna()
car_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
# How to create a dataframe
# Column from series
seats_column = pd.Series([5,5,5,5,5])

# New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales.Seats.fillna(5, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
# Column from Python list
fuel_economy = [7,5, 9.2, 5.0, 9.6, 8.7]
car_sales["Fuel/100KM"] = fuel_economy
car_sales
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-df9af59e4ba1> in <module>
#       1 # Column from Python list
#       2 fuel_economy = [7,5, 9.2, 5.0, 9.6, 8.7]
# ----> 3 car_sales["Fuel/100KM"] = fuel_economy
#       4 car_sales
#
# /users/efe/Desktop/sample/env/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# /users/efe/Desktop/sample/env/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3118         """
#    3119         self._ensure_valid_index(value)
# -> 3120         value = self._sanitize_column(key, value)
#    3121         NDFrame._set_item(self, key, value)
#    3122
#
# ...

# %%
# So the list must be as long as the dataframe length;
fuel_economy = [7,5, 9.2, 5.0, 9.6, 8.7, 4.7, 5.6, 4.5, 12.2]
#fuel economy has the same length as car_sales
car_sales["Fuel/100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel/100KM
# 0  toyota  White         150043      4   400000    5.0         7.0
# 1   honda    Red          87899      4   500000    5.0         5.0
# 2  toyota   Blue          32549      3   700000    5.0         9.2
# 3     bmw  Black          11179      5  2200000    5.0         5.0
# 4  nissan  White         213095      4   350000    5.0         9.6
# 5  toyota  Green          99213      4   450000    5.0         8.7
# 6   honda   Blue          45698      4   750000    5.0         4.7
# 7   honda   Blue          54738      4   700000    5.0         5.6
# 8  toyota  White          60000      4   625000    5.0         4.5
# 9  nissan  White          31600      4   970000    5.0        12.2

# %%
#Example: make column of how much fuel used;
car_sales["Total Fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel/100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel/100KM  \
# 0  toyota  White         150043      4   400000    5.0         7.0
# 1   honda    Red          87899      4   500000    5.0         5.0
# 2  toyota   Blue          32549      3   700000    5.0         9.2
# 3     bmw  Black          11179      5  2200000    5.0         5.0
# 4  nissan  White         213095      4   350000    5.0         9.6
# 5  toyota  Green          99213      4   450000    5.0         8.7
# 6   honda   Blue          45698      4   750000    5.0         4.7
# 7   honda   Blue          54738      4   700000    5.0         5.6
# 8  toyota  White          60000      4   625000    5.0         4.5
# 9  nissan  White          31600      4   970000    5.0        12.2
#
#    Total Fuel used (L)
# 0            10503.010
# 1             4394.950
# 2             2994.508
# 3              558.950
# 4            20457.120
# 5             8631.531
# 6             2147.806
# 7             3065.328
# ...

# %%
# create a column from a single value
car_sales["Number of Wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel/100KM  \
# 0  toyota  White         150043      4   400000    5.0         7.0
# 1   honda    Red          87899      4   500000    5.0         5.0
# 2  toyota   Blue          32549      3   700000    5.0         9.2
# 3     bmw  Black          11179      5  2200000    5.0         5.0
# 4  nissan  White         213095      4   350000    5.0         9.6
# 5  toyota  Green          99213      4   450000    5.0         8.7
# 6   honda   Blue          45698      4   750000    5.0         4.7
# 7   honda   Blue          54738      4   700000    5.0         5.6
# 8  toyota  White          60000      4   625000    5.0         4.5
# 9  nissan  White          31600      4   970000    5.0        12.2
#
#    Total Fuel used (L)  Number of Wheels
# 0            10503.010                 4
# 1             4394.950                 4
# 2             2994.508                 4
# 3              558.950                 4
# ...

# %%
# add more column
car_sales["Passed road safety"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel/100KM  \
# 0  toyota  White         150043      4   400000    5.0         7.0
# 1   honda    Red          87899      4   500000    5.0         5.0
# 2  toyota   Blue          32549      3   700000    5.0         9.2
# 3     bmw  Black          11179      5  2200000    5.0         5.0
# 4  nissan  White         213095      4   350000    5.0         9.6
# 5  toyota  Green          99213      4   450000    5.0         8.7
# 6   honda   Blue          45698      4   750000    5.0         4.7
# 7   honda   Blue          54738      4   700000    5.0         5.6
# 8  toyota  White          60000      4   625000    5.0         4.5
# 9  nissan  White          31600      4   970000    5.0        12.2
#
#    Total Fuel used (L)  Number of Wheels  Passed road safety
# 0            10503.010                 4                True
# 1             4394.950                 4                True
# ...

# %%
# How to remove a column
car_sales.drop("Number of Wheels", axis=1)
# axis=1 is important because the columns start at 1 , not 0
# also do the follwing
car_sales = car_sales.drop("Number of Wheels", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel/100KM  \
# 0  toyota  White         150043      4   400000    5.0         7.0
# 1   honda    Red          87899      4   500000    5.0         5.0
# 2  toyota   Blue          32549      3   700000    5.0         9.2
# 3     bmw  Black          11179      5  2200000    5.0         5.0
# 4  nissan  White         213095      4   350000    5.0         9.6
# 5  toyota  Green          99213      4   450000    5.0         8.7
# 6   honda   Blue          45698      4   750000    5.0         4.7
# 7   honda   Blue          54738      4   700000    5.0         5.6
# 8  toyota  White          60000      4   625000    5.0         4.5
# 9  nissan  White          31600      4   970000    5.0        12.2
#
#    Total Fuel used (L)  Passed road safety
# 0            10503.010                True
# 1             4394.950                True
# 2             2994.508                True
# 3              558.950                True
# ...

# %%
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel/100KM  \
# 8  toyota  White          60000      4   625000    5.0         4.5
# 0  toyota  White         150043      4   400000    5.0         7.0
# 6   honda   Blue          45698      4   750000    5.0         4.7
# 3     bmw  Black          11179      5  2200000    5.0         5.0
# 4  nissan  White         213095      4   350000    5.0         9.6
#
#    Total Fuel used (L)  Passed road safety
# 8             2700.000                True
# 0            10503.010                True
# 6             2147.806                True
# 3              558.950                True
# 4            20457.120                True

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel/100KM  \
# 5  toyota  Green          99213      4   450000    5.0         8.7
# 7   honda   Blue          54738      4   700000    5.0         5.6
# 6   honda   Blue          45698      4   750000    5.0         4.7
# 2  toyota   Blue          32549      3   700000    5.0         9.2
# 8  toyota  White          60000      4   625000    5.0         4.5
# 3     bmw  Black          11179      5  2200000    5.0         5.0
# 1   honda    Red          87899      4   500000    5.0         5.0
# 0  toyota  White         150043      4   400000    5.0         7.0
# 4  nissan  White         213095      4   350000    5.0         9.6
# 9  nissan  White          31600      4   970000    5.0        12.2
#
#    Total Fuel used (L)  Passed road safety
# 5             8631.531                True
# 7             3065.328                True
# 6             2147.806                True
# 2             2994.508                True
# ...

# %%
# only select 20% of arbitrary data
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel/100KM  \
# 8  toyota  White          60000      4  625000    5.0         4.5
# 7   honda   Blue          54738      4  700000    5.0         5.6
#
#    Total Fuel used (L)  Passed road safety
# 8             2700.000                True
# 7             3065.328                True

# %%
car_sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel/100KM  \
# 0      5  toyota  Green          99213      4   450000    5.0         8.7
# 1      7   honda   Blue          54738      4   700000    5.0         5.6
# 2      6   honda   Blue          45698      4   750000    5.0         4.7
# 3      2  toyota   Blue          32549      3   700000    5.0         9.2
# 4      8  toyota  White          60000      4   625000    5.0         4.5
# 5      3     bmw  Black          11179      5  2200000    5.0         5.0
# 6      1   honda    Red          87899      4   500000    5.0         5.0
# 7      0  toyota  White         150043      4   400000    5.0         7.0
# 8      4  nissan  White         213095      4   350000    5.0         9.6
# 9      9  nissan  White          31600      4   970000    5.0        12.2
#
#    Total Fuel used (L)  Passed road safety
# 0             8631.531                True
# 1             3065.328                True
# ...

# %%
# To get rid of he 'index' column;
# inplace=True puts the indexes in order again
car_sales_shuffled.reset_index(drop=True, inplace=True)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel/100KM  \
# 0  toyota  Green          99213      4   450000    5.0         8.7
# 1   honda   Blue          54738      4   700000    5.0         5.6
# 2   honda   Blue          45698      4   750000    5.0         4.7
# 3  toyota   Blue          32549      3   700000    5.0         9.2
# 4  toyota  White          60000      4   625000    5.0         4.5
# 5     bmw  Black          11179      5  2200000    5.0         5.0
# 6   honda    Red          87899      4   500000    5.0         5.0
# 7  toyota  White         150043      4   400000    5.0         7.0
# 8  nissan  White         213095      4   350000    5.0         9.6
# 9  nissan  White          31600      4   970000    5.0        12.2
#
#    Total Fuel used (L)  Passed road safety
# 0             8631.531                True
# 1             3065.328                True
# 2             2147.806                True
# 3             2994.508                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)

# %%
# Odometer values are now in miles
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel/100KM  \
# 0  toyota  White      93776.875      4   400000    5.0         7.0
# 1   honda    Red      54936.875      4   500000    5.0         5.0
# 2  toyota   Blue      20343.125      3   700000    5.0         9.2
# 3     bmw  Black       6986.875      5  2200000    5.0         5.0
# 4  nissan  White     133184.375      4   350000    5.0         9.6
# 5  toyota  Green      62008.125      4   450000    5.0         8.7
# 6   honda   Blue      28561.250      4   750000    5.0         4.7
# 7   honda   Blue      34211.250      4   700000    5.0         5.6
# 8  toyota  White      37500.000      4   625000    5.0         4.5
# 9  nissan  White      19750.000      4   970000    5.0        12.2
#
#    Total Fuel used (L)  Passed road safety
# 0            10503.010                True
# 1             4394.950                True
# 2             2994.508                True
# 3              558.950                True
# ...

# %%
# Try it, run your code
# Search for it
# Try again
# Ask
